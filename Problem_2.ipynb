# %% [markdown]
# # Problem 2: Getting familiar with TensorFlow
#
# *TensorFlow* is one of the most popular deep learning framework developed by Google. If you are new to TensorFlow, please read and play with the sample in [Getting started with TensorFlow](https://www.tensorflow.org/get_started/get_started) to get started.
#
# * <b>Learning Objective:</b> In Problem 1, you implemented a fully connected network from scratch on your own. Very tedious to do it all by yourself, right? Well, we actually feel the same thing, that's why we are using tools instead of doing everything from scratch. For this part of the assignment, we will familiarize you with a widely-used deep learning framework developed by Google, TensorFlow and walk you through convolutional neural networks and show how to train them.
# * <b>Provided Codes:</b> We provide the Template class for a simple CNN model as BaseModel, predefined skeletons for conv2d() and max_pool(), as well as the dataset preprocessing parts.
# * <b>TODOs:</b> You are asked to implement the BaseModel following the detailed instructions and design your own model in YourModel to achieve a reasonably good performance for classification task on CIFAR-10 dataset.

# %% [markdown]
# ## Import libraries

# %%
# Import required libraries
# Add whatever you want
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from lib.datasets import CIFAR10_tf

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print("TensorFlow Version {}".format(tf.__version__))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# TensorFlow Version 1.12.0

# %%
# Test matplotlib
x = np.linspace(-3, 3, 100)

plt.plot(x, np.maximum(0, x), label='relu')
plt.plot(x, 1/(1 + np.exp(-x)), label='sigmoid')
plt.plot(x, (1 - np.exp(-2 * x))/(1 + np.exp(-2 * x)), label='tanh')

plt.xlabel('x')
plt.ylabel('y')

plt.title("Activation functions")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Test tensorflow
print('TensorFlow version: ' + tf.__version__)
a = tf.constant(2.0)
b = tf.constant(3.0)
c = a * b

sess = tf.Session()
result = sess.run([a, b, c])
print('%f * %f = %f' % (result[0], result[1], result[2]))
sess.close()
# Out:
# TensorFlow version: 1.12.0
# 2.000000 * 3.000000 = 6.000000

# %% [markdown]
# ## Load datasets
# Download [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz) and load the dataset. In this assignment, we will use the standard 50,000 images for training and 10,000 images for test.

# %%
# Configuration
num_training = 49000
num_validation = 50000 - num_training
num_test = 10000

data = CIFAR10_tf(num_training=num_training,
                  num_validation=num_validation,
                  num_test=num_test)

# Load cifar-10 data
X_train, Y_train = data['data_train'], data['labels_train']
X_val, Y_val = data['data_val'], data['labels_val']
X_test, Y_test = data['data_test'], data['labels_test']

# Check the shape of the dataset
assert X_train.shape == (num_training, 32, 32, 3)
assert Y_train.shape == (num_training, )
assert X_val.shape == (num_validation, 32, 32, 3)
assert Y_val.shape == (num_validation, )
assert X_test.shape == (num_test, 32, 32, 3)
assert Y_test.shape == (10000, )

# %% [markdown]
# ## Question 2-1
#
# Using the code provided, implement a neural network architecture with an optimization routine according to the specification provided below.
#
# **Model:**
# - Input image with the size 32x32x3
# - 7x7 convolutional layer with 32 filters, stride of 1, and padding 'SAME'
# - ReLU activation layer
# - 3x3 max pooling layer with a stride of 2
# - 5x5 convolutional layer with 64 filters, stride of 1, and padding 'SAME'
# - ReLU activation layer
# - 3x3 max pooling layer with a stride of 2
# - Flatten layer (8x8x64 -> 4096)
# - Fully-connected layer with 384 output units (4096 -> 384)
# - ReLU activation layer
# - Fully-connected layer with 10 output units (384 -> 10)
# - Output logits (10)
#
# **Optimizer:**
# - Adam optimizer
#
# **Learning rate:**
# - Set start learning rate as 5e-4 and apply exponential decay every 500 steps with a base of 0.96
# - Use 'tf.train.exponential_decay' and 'tf.train.AdamOptimizer'
#
# **Loss:**
# - Softmax cross entropy loss
# - Use 'tf.nn.softmax_cross_entropy_with_logits'
#
#
# Your model **should** achieve about 60% accuracy on validation set in 5 epochs using provided evaluation code.
#
# You can modify the template code as you want.

# %% [markdown]
# ## Define your layers

# %%
# Define max pooling and conv layers

def conv2d(input, kernel_size, stride, num_filter):
    stride_shape = [1, stride, stride, 1]
    filter_shape = [kernel_size, kernel_size, input.get_shape()[3], num_filter]

    W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
    b = tf.get_variable('b', [1, 1, 1, num_filter], initializer=tf.constant_initializer(0.0))
    return tf.nn.conv2d(input, W, stride_shape, padding='SAME') + b

def max_pool(input, kernel_size, stride):
    ksize = [1, kernel_size, kernel_size, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.max_pool(input, ksize=ksize, strides=strides, padding='SAME')

#############################################################################
# TODO: Complete the following functions                                    #
#############################################################################
def flatten(input):
    """
        - input: input tensors
    """
    return tf.layers.flatten(input)

def fc(input, num_output):
    """
        - input: input tensors
        - num_output: int, the output dimension
    """
    return tf.contrib.layers.fully_connected(input, num_output,
                                            activation_fn = None)

def norm(input, is_training):
    """
        - input: input tensors
        - is_training: boolean, if during training or not
    """
    return None

def train_preprocess(image, is_Training=True):
    if is_Training:
        image = tf.image.random_flip_left_right(image)

        image = tf.image.random_brightness(image, max_delta=32.0 / 255.0)
        image = tf.image.random_saturation(image, lower=0.5, upper=1.5)

        #image = tf.clip_by_value(image, 0.0, 1.0)

        return image
#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

# %% [markdown]
# ## Sample convolutional neural network

# %%
class BaseModel(object):
    def __init__(self):
        self.num_epoch = 5
        self.batch_size = 128
        self.log_step = 50
        self._build_model()

    def _model(self):
        print('-' * 5 + '  Sample model  ' + '-' * 5)

        print('intput layer: ' + str(self.X.get_shape()))

        with tf.variable_scope('conv1'):
            self.conv1 = conv2d(self.X, 7, 1, 32)
            self.relu1 = tf.nn.relu(self.conv1)
            self.pool1 = max_pool(self.relu1, 3, 2)            
            print('conv1 layer: ' + str(self.pool1.get_shape()))

        with tf.variable_scope('conv2'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.conv2 = conv2d(self.pool1, 5, 1, 64)
            self.relu2 = tf.nn.relu(self.conv2)
            self.pool2 = max_pool(self.relu2, 3, 2)
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('conv2 layer: ' + str(self.pool2.get_shape()))

        #############################################################################
        # TODO: Flatten the output tensor from conv2 layer                          #
        #############################################################################
        self.flat = flatten(self.pool2)
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################      
        print('flat layer: ' + str(self.flat.get_shape()))

        with tf.variable_scope('fc3'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.fc3 = fc(self.flat, 384)
            self.relu3 = tf.nn.relu(self.fc3)
            
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('fc3 layer: ' + str(self.relu3.get_shape()))
            
        with tf.variable_scope('fc4'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.fc4 = fc(self.relu3, 10)
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('fc4 layer: ' + str(self.fc4.get_shape()))
            
        # Return the last layer
        return self.fc4

    def _input_ops(self):
        # Placeholders
        self.X = tf.placeholder(tf.float32, [None, 32, 32, 3])
        self.Y = tf.placeholder(tf.int64, [None])

        #############################################################################
        # TODO: You can add any placeholders                                        #
        #############################################################################
        self.global_step = tf.Variable(0, trainable = False)
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def _build_optimizer(self):
        # Adam optimizer 'self.train_op' that minimizes 'self.loss_op'
        #############################################################################
        # TODO: Complete the following functions                                    #
        #############################################################################
        start_learning_rate = 5e-4
        learning_rate = tf.train.exponential_decay(start_learning_rate,
                                                  self.global_step,
                                                  500,
                                                  0.96)
        
        self.train_op = tf.train.AdamOptimizer(learning_rate
                                              ).minimize(self.loss_op,
                                                        global_step = self.global_step)
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################
        
    def _loss(self, labels, logits):
        # Softmax cross entropy loss 'self.loss_op'
        #############################################################################
        # TODO: Complete the following functions                                    #
        #############################################################################
        self.loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(None, labels, logits))
                                                               
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def _build_model(self):
        # Define input variables
        self._input_ops()

        # Convert Y to one-hot vector
        labels = tf.one_hot(self.Y, 10)

        # Build a model and get logits
        logits = self._model()

        # Compute loss
        self._loss(labels, logits)
        
        # Build optimizer
        self._build_optimizer()

        # Compute accuracy
        predict = tf.argmax(logits, 1)
        correct = tf.equal(predict, self.Y)
        self.accuracy_op = tf.reduce_mean(tf.cast(correct, tf.float32))
        
    def train(self, sess, X_train, Y_train, X_val, Y_val):
        sess.run(tf.global_variables_initializer())

        step = 0
        losses = []
        accuracies = []
        print('-' * 5 + '  Start training  ' + '-' * 5)
        for epoch in range(self.num_epoch):
            print('train for epoch %d' % epoch)
            for i in range(num_training // self.batch_size):
                X_ = X_train[i * self.batch_size:(i + 1) * self.batch_size][:]
                Y_ = Y_train[i * self.batch_size:(i + 1) * self.batch_size]

                #############################################################################
                # TODO: You can change feed data as you want                                #
                #############################################################################
                
                #shuffle_index = np.arange(Y_.shape[0])
                #np.random.shuffle(shuffle_index)
                
                #feed_dict = {self.X:X_[shuffle_index], self.Y:Y_[shuffle_index]}
                
                feed_dict = {self.X:X_, self.Y:Y_}
                #############################################################################
                #                             END OF YOUR CODE                              #
                #############################################################################
                fetches = [self.train_op, self.loss_op, self.accuracy_op]

                _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
                losses.append(loss)
                accuracies.append(accuracy)

                if step % self.log_step == 0:
                    
                    print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                        (step, loss, accuracy))
                step += 1

            # Print validation results
            print('validation for epoch %d' % epoch)
            val_accuracy = self.evaluate(sess, X_val, Y_val)
            print('-  epoch %d: validation accuracy = %.3f' % (epoch, val_accuracy))
            
        #############################################################################
        # TODO: Plot training curve                                                 #
        #############################################################################
        # Graph 1. X: epoch, Y: training loss
        
        plt.title("Training Losses")
        plt.xlabel("Epoch")
        epoches = np.arange(0, self.num_epoch, self.num_epoch / len(losses))
        #plt.plot(losses[len(losses) // self.num_epoch - 1::len(losses) // self.num_epoch])
        plt.plot(epoches, losses)
        plt.gcf().set_size_inches(15, 15)
        plt.show()
        
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def evaluate(self, sess, X_eval, Y_eval):
        eval_accuracy = 0.0
        eval_iter = 0
        for i in range(X_eval.shape[0] // self.batch_size):
            X_ = X_eval[i * self.batch_size:(i + 1) * self.batch_size][:]
            Y_ = Y_eval[i * self.batch_size:(i + 1) * self.batch_size]
            
            #############################################################################
            # TODO: You can change feed data as you want                                #
            #############################################################################
            feed_dict = {self.X:X_, self.Y:Y_}
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            accuracy = sess.run(self.accuracy_op, feed_dict=feed_dict)
            eval_accuracy += accuracy
            eval_iter += 1
        return eval_accuracy / eval_iter

# %%
# Clear old computation graphs
tf.reset_default_graph()

# Train our sample model
with tf.Session() as sess:
    with tf.device('/cpu:0'):
        model = BaseModel()
        model.train(sess, X_train, Y_train, X_val, Y_val)
        accuracy = model.evaluate(sess, X_test, Y_test)
        print('***** test accuracy: %.3f' % accuracy)
        saver = tf.train.Saver()
        model_path = saver.save(sess, "lib/tf_models/problem2/csci-599_sample.ckpt")
        print("Model saved in %s" % model_path)
# Out:
# -----  Sample model  -----
# intput layer: (?, 32, 32, 3)
# conv1 layer: (?, 16, 16, 32)
# conv2 layer: (?, 8, 8, 64)
# flat layer: (?, 4096)
# fc3 layer: (?, 384)
# fc4 layer: (?, 10)
# -----  Start training  -----
# train for epoch 0
# iteration (0): loss = 13.782, accuracy = 0.094
# iteration (50): loss = 2.049, accuracy = 0.250
# iteration (100): loss = 1.936, accuracy = 0.320
# iteration (150): loss = 1.779, accuracy = 0.352
# iteration (200): loss = 1.763, accuracy = 0.430
# iteration (250): loss = 1.597, accuracy = 0.445
# iteration (300): loss = 1.475, accuracy = 0.469
# iteration (350): loss = 1.582, accuracy = 0.414
# validation for epoch 0
# -  epoch 0: validation accuracy = 0.528
# train for epoch 1
# iteration (400): loss = 1.511, accuracy = 0.406
# iteration (450): loss = 1.420, accuracy = 0.508
# iteration (500): loss = 1.351, accuracy = 0.469
# iteration (550): loss = 1.246, accuracy = 0.555
# iteration (600): loss = 1.351, accuracy = 0.586
# iteration (650): loss = 1.460, accuracy = 0.469
# iteration (700): loss = 1.344, accuracy = 0.539
# iteration (750): loss = 1.147, accuracy = 0.500
# validation for epoch 1
# -  epoch 1: validation accuracy = 0.558
# train for epoch 2
# iteration (800): loss = 1.117, accuracy = 0.625
# iteration (850): loss = 1.337, accuracy = 0.547
# iteration (900): loss = 1.144, accuracy = 0.617
# iteration (950): loss = 1.119, accuracy = 0.633
# iteration (1000): loss = 1.164, accuracy = 0.586
# iteration (1050): loss = 1.141, accuracy = 0.625
# iteration (1100): loss = 1.102, accuracy = 0.586
# validation for epoch 2
# -  epoch 2: validation accuracy = 0.590
# train for epoch 3
# iteration (1150): loss = 1.102, accuracy = 0.586
# iteration (1200): loss = 0.973, accuracy = 0.625
# iteration (1250): loss = 1.123, accuracy = 0.633
# iteration (1300): loss = 1.154, accuracy = 0.586
# iteration (1350): loss = 1.055, accuracy = 0.586
# iteration (1400): loss = 1.068, accuracy = 0.617
# iteration (1450): loss = 1.089, accuracy = 0.625
# iteration (1500): loss = 0.889, accuracy = 0.695
# validation for epoch 3
# -  epoch 3: validation accuracy = 0.606
# train for epoch 4
# iteration (1550): loss = 0.856, accuracy = 0.688
# iteration (1600): loss = 1.037, accuracy = 0.609
# iteration (1650): loss = 1.094, accuracy = 0.562
# iteration (1700): loss = 0.812, accuracy = 0.727
# iteration (1750): loss = 0.896, accuracy = 0.680
# iteration (1800): loss = 0.985, accuracy = 0.633
# iteration (1850): loss = 0.982, accuracy = 0.633
# iteration (1900): loss = 0.922, accuracy = 0.695
# validation for epoch 4
# -  epoch 4: validation accuracy = 0.617
# ***** test accuracy: 0.610
# Model saved in lib/tf_models/problem2/csci-599_sample.ckpt

# %% [markdown]
# ## Question 2-2
#
# Implement your own model.
#
# You can modify the template code as you want and you can use GPU for fast training.
# For GPU usage, simply change the following line of the training block:
# from `with tf.device('/cpu:0')` to `with tf.device('/GPU:0')`
# and you can set your desired device number
#
# These are the techniques that you can try:
# - Data preprocessing
# - Data augmentation
# - Dropout
# - Batch normalization
# - More convolutional layers
# - More training epochs
# - Learning rate decay
# - Any other models and techniqes
#
# Your model should achieve >= 70% accuracy on the test set of CIFAR-10.
#
# If the accuracy of the model reaches to 80%, you will get 5 extra points.

# %%
class YourModel(BaseModel):
    def __init__(self):
        super(YourModel, self).__init__()
        self.num_epoch = 20
        self.batch_size = 128
        self.log_step = 50
        #self._build_model()

    def _model(self):
        print('-' * 5 + '  Your model  ' + '-' * 5)

        #############################################################################
        # TODO: Implement you own model here                                        #
        #############################################################################
        
        
        #############################################
        # By Li Pengcheng
        
        # We use an architecture similar to vgg's: every two 3x3 convolutional layers are
        # followed by a max pooling layer. And the number of kernels are doubled as layers
        # go deeper. We use a 3x3 max_pooling layer with stride as 2.
        
        # After all the convolutional layers, we use two dense layers.
        
        # The activation function we use is elu.
        
        # Additionally, we use dropout in the first dense layer. The droput probability is 
        # set to be 0.5 as the most common one.
        
        # We rewrite the train function because we try to feed the training data in a
        # shuffled way.
        
        # Finally, we also try to augment the data by flipping it left-right, or modifying
        # brightness or saturation.
        
        # After 10-20 epochs, the network would achieve 80%+ on the test set.
        
        #############################################
        
        print("input layer: " + str(self.X.get_shape))
        
        with tf.variable_scope("conv1a"):
            self.conv1a = conv2d(train_preprocess(self.X), 3, 1, 64)
        with tf.variable_scope("conv1b"):
            self.conv1b = conv2d(self.conv1a, 3, 1, 64)
            self.elu1 = tf.nn.elu(self.conv1b)
            self.pool1 = max_pool(self.elu1, 3, 2)
            print("conv1 layer: " + str(self.pool1.get_shape()))
            
        with tf.variable_scope("conv2a"):
            self.conv2a = conv2d(self.pool1, 3, 1, 128)
        with tf.variable_scope("conv2b"):
            self.conv2b = conv2d(self.conv2a, 3, 1, 128)
            self.elu2 = tf.nn.elu(self.conv2b)
            self.pool2 = max_pool(self.elu2, 3, 2)
            print("conv2 layer: " + str(self.pool2.get_shape()))
            
        with tf.variable_scope("conv3a"):
            self.conv3a = conv2d(self.pool2, 3, 1, 256)
        with tf.variable_scope("conv3b"):
            self.conv3b = conv2d(self.conv3a, 3, 1, 256)
            self.elu3 = tf.nn.elu(self.conv3b)
            self.pool3 = max_pool(self.elu3, 3, 2)
            print("conv3 layer: " + str(self.pool3.get_shape()))
            
        with tf.variable_scope("flatten"):
            self.flat = flatten(self.pool3)
            print("flat layer: " + str(self.flat.get_shape()))
            
        with tf.variable_scope("fcFour"):
            self.fc4 = tf.nn.dropout(fc(self.flat, 384), keep_prob = 0.5)
            self.elu4 = tf.nn.elu(self.fc4)
            print("fc4 layer: " + str(self.elu4.get_shape()))
            
        with tf.variable_scope("fcFive"):
            self.fc5 = fc(self.elu4, 10)
            print("fc5 layer: " + str(self.fc5.get_shape()))
            
        return self.fc5


    
    def train(self, sess, X_train, Y_train, X_val, Y_val):
        
        sess.run(tf.global_variables_initializer())

        best_saver = tf.train.Saver()
        opt_val_accuracy = 0
        
        step = 0
        losses = []
        accuracies = []
        print("-" * 5 + "  Start training  " + "-" * 5)
        
        for epoch in range(self.num_epoch):
            print("train for epoch %d" % epoch)
            for i in range(num_training // self.batch_size):
                X_ = X_train[i * self.batch_size : (i + 1) * self.batch_size][:]
                Y_ = Y_train[i * self.batch_size : (i + 1) * self.batch_size]
                
                shuffle_index = np.arange(Y_.shape[0])
                np.random.shuffle(shuffle_index)
                
                feed_dict = {self.X:X_[shuffle_index], self.Y:Y_[shuffle_index]}
                
                fetches = [self.train_op, self.loss_op, self.accuracy_op]
                
                _, loss, accuracy = sess.run(fetches, feed_dict = feed_dict)
                
                losses.append(loss)
                accuracies.append(accuracy)
                
                if step % self.log_step == 0:
                    print("iteration (%d): loss = %.3f, accuracy = %.3f" % 
                         (step, loss, accuracy))
                    
                step += 1
                
            print("validation for epoch %d" % epoch)
                
            val_accuracy = self.evaluate(sess, X_val, Y_val)
                
            print("- epoch %d: validation accuracy = %.3f" % (epoch, val_accuracy))
                
            if val_accuracy > opt_val_accuracy:
                opt_val_accuracy = val_accuracy
                best_saver.save(sess, "lib/tf_models/problem2/csci-599_my_best.ckpt")
    
        plt.title("Training Losses")
        plt.xlabel("Epoch")
        epoches = np.arange(0, self.num_epoch, self.num_epoch / len(losses))
        #plt.plot(losses[len(losses) // self.num_epoch - 1::len(losses) // self.num_epoch])
        plt.plot(epoches, losses)
        plt.gcf().set_size_inches(15, 15)
        plt.show()
        
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

# %%
# Clear old computation graphs
tf.reset_default_graph()

#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

with tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)) as sess:
    with tf.device('/cpu:0'):
        model = YourModel()
        model.train(sess, X_train, Y_train, X_val, Y_val)
        accuracy = model.evaluate(sess, X_test, Y_test)
        print('***** test accuracy: %.3f' % accuracy)
        # Save your model
        saver = tf.train.Saver()
        model_path = saver.save(sess, "lib/tf_models/problem2/csci-599_mine.ckpt")
        print("Model saved in %s" % model_path)
# Out:
# -----  Your model  -----
# input layer: <bound method Tensor.get_shape of <tf.Tensor 'Placeholder:0' shape=(?, 32, 32, 3) dtype=float32>>
# conv1 layer: (?, 16, 16, 64)
# conv2 layer: (?, 8, 8, 128)
# conv3 layer: (?, 4, 4, 256)
# flat layer: (?, 4096)
# fc4 layer: (?, 384)
# fc5 layer: (?, 10)
# -----  Start training  -----
# train for epoch 0
# iteration (0): loss = 2.914, accuracy = 0.102
# iteration (50): loss = 1.754, accuracy = 0.359
# iteration (100): loss = 1.555, accuracy = 0.391
# iteration (150): loss = 1.362, accuracy = 0.500
# iteration (200): loss = 1.414, accuracy = 0.492
# iteration (250): loss = 1.299, accuracy = 0.570
# iteration (300): loss = 1.153, accuracy = 0.586
# iteration (350): loss = 1.191, accuracy = 0.617
# validation for epoch 0
# - epoch 0: validation accuracy = 0.679
# train for epoch 1
# iteration (400): loss = 0.952, accuracy = 0.664
# iteration (450): loss = 1.110, accuracy = 0.602
# iteration (500): loss = 0.956, accuracy = 0.625
# iteration (550): loss = 0.977, accuracy = 0.695
# iteration (600): loss = 0.707, accuracy = 0.773
# iteration (650): loss = 1.020, accuracy = 0.680
# iteration (700): loss = 0.870, accuracy = 0.719
# iteration (750): loss = 0.786, accuracy = 0.734
# validation for epoch 1
# - epoch 1: validation accuracy = 0.718
# train for epoch 2
# iteration (800): loss = 0.931, accuracy = 0.711
# iteration (850): loss = 0.737, accuracy = 0.703
# iteration (900): loss = 0.957, accuracy = 0.680
# iteration (950): loss = 0.744, accuracy = 0.750
# iteration (1000): loss = 0.683, accuracy = 0.805
# iteration (1050): loss = 0.774, accuracy = 0.797
# iteration (1100): loss = 0.631, accuracy = 0.828
# validation for epoch 2
# - epoch 2: validation accuracy = 0.731
# train for epoch 3
# iteration (1150): loss = 0.806, accuracy = 0.742
# iteration (1200): loss = 0.561, accuracy = 0.805
# iteration (1250): loss = 0.826, accuracy = 0.758
# iteration (1300): loss = 0.965, accuracy = 0.711
# iteration (1350): loss = 0.613, accuracy = 0.781
# iteration (1400): loss = 0.631, accuracy = 0.828
# iteration (1450): loss = 0.591, accuracy = 0.820
# iteration (1500): loss = 0.505, accuracy = 0.828
# validation for epoch 3
# - epoch 3: validation accuracy = 0.749
# train for epoch 4
# iteration (1550): loss = 0.517, accuracy = 0.836
# iteration (1600): loss = 0.730, accuracy = 0.781
# iteration (1650): loss = 0.786, accuracy = 0.789
# iteration (1700): loss = 0.704, accuracy = 0.719
# iteration (1750): loss = 0.672, accuracy = 0.797
# iteration (1800): loss = 0.650, accuracy = 0.781
# iteration (1850): loss = 0.651, accuracy = 0.773
# iteration (1900): loss = 0.736, accuracy = 0.742
# validation for epoch 4
# - epoch 4: validation accuracy = 0.756
# train for epoch 5
# iteration (1950): loss = 0.639, accuracy = 0.789
# iteration (2000): loss = 0.532, accuracy = 0.812
# iteration (2050): loss = 0.591, accuracy = 0.805
# iteration (2100): loss = 0.676, accuracy = 0.797
# iteration (2150): loss = 0.873, accuracy = 0.719
# iteration (2200): loss = 0.684, accuracy = 0.727
# iteration (2250): loss = 0.623, accuracy = 0.742
# validation for epoch 5
# - epoch 5: validation accuracy = 0.769
# train for epoch 6
# iteration (2300): loss = 0.487, accuracy = 0.844
# iteration (2350): loss = 0.439, accuracy = 0.844
# iteration (2400): loss = 0.522, accuracy = 0.828
# iteration (2450): loss = 0.606, accuracy = 0.820
# iteration (2500): loss = 0.703, accuracy = 0.750
# iteration (2550): loss = 0.710, accuracy = 0.812
# iteration (2600): loss = 0.501, accuracy = 0.805
# iteration (2650): loss = 0.477, accuracy = 0.844
# validation for epoch 6
# - epoch 6: validation accuracy = 0.779
# train for epoch 7
# iteration (2700): loss = 0.754, accuracy = 0.820
# iteration (2750): loss = 0.651, accuracy = 0.781
# iteration (2800): loss = 0.673, accuracy = 0.805
# iteration (2850): loss = 0.324, accuracy = 0.867
# iteration (2900): loss = 0.306, accuracy = 0.891
# iteration (2950): loss = 0.463, accuracy = 0.812
# iteration (3000): loss = 0.377, accuracy = 0.883
# iteration (3050): loss = 0.532, accuracy = 0.852
# validation for epoch 7
# - epoch 7: validation accuracy = 0.790
# train for epoch 8
# iteration (3100): loss = 0.627, accuracy = 0.812
# iteration (3150): loss = 0.574, accuracy = 0.805
# iteration (3200): loss = 0.564, accuracy = 0.766
# iteration (3250): loss = 0.372, accuracy = 0.852
# iteration (3300): loss = 0.462, accuracy = 0.820
# iteration (3350): loss = 0.396, accuracy = 0.844
# iteration (3400): loss = 0.404, accuracy = 0.883
# validation for epoch 8
# - epoch 8: validation accuracy = 0.805
# train for epoch 9
# iteration (3450): loss = 0.524, accuracy = 0.859
# iteration (3500): loss = 0.610, accuracy = 0.812
# iteration (3550): loss = 0.414, accuracy = 0.859
# iteration (3600): loss = 0.421, accuracy = 0.852
# iteration (3650): loss = 0.494, accuracy = 0.828
# iteration (3700): loss = 0.608, accuracy = 0.750
# iteration (3750): loss = 0.498, accuracy = 0.828
# iteration (3800): loss = 0.415, accuracy = 0.820
# validation for epoch 9
# - epoch 9: validation accuracy = 0.796
# train for epoch 10
# iteration (3850): loss = 0.439, accuracy = 0.867
# iteration (3900): loss = 0.381, accuracy = 0.875
# iteration (3950): loss = 0.400, accuracy = 0.844
# iteration (4000): loss = 0.339, accuracy = 0.867
# iteration (4050): loss = 0.418, accuracy = 0.828
# iteration (4100): loss = 0.274, accuracy = 0.891
# iteration (4150): loss = 0.288, accuracy = 0.883
# iteration (4200): loss = 0.414, accuracy = 0.867
# validation for epoch 10
# - epoch 10: validation accuracy = 0.818
# train for epoch 11
# iteration (4250): loss = 0.411, accuracy = 0.883
# iteration (4300): loss = 0.367, accuracy = 0.812
# iteration (4350): loss = 0.434, accuracy = 0.867
# iteration (4400): loss = 0.312, accuracy = 0.938
# iteration (4450): loss = 0.451, accuracy = 0.836
# iteration (4500): loss = 0.396, accuracy = 0.883
# iteration (4550): loss = 0.269, accuracy = 0.883
# validation for epoch 11
# - epoch 11: validation accuracy = 0.788
# train for epoch 12
# iteration (4600): loss = 0.408, accuracy = 0.836
# iteration (4650): loss = 0.463, accuracy = 0.859
# iteration (4700): loss = 0.439, accuracy = 0.836
# iteration (4750): loss = 0.306, accuracy = 0.898
# iteration (4800): loss = 0.348, accuracy = 0.875
# iteration (4850): loss = 0.276, accuracy = 0.930
# iteration (4900): loss = 0.327, accuracy = 0.914
# iteration (4950): loss = 0.329, accuracy = 0.883
# validation for epoch 12
# - epoch 12: validation accuracy = 0.818
# train for epoch 13
# iteration (5000): loss = 0.212, accuracy = 0.930
# iteration (5050): loss = 0.360, accuracy = 0.891
# iteration (5100): loss = 0.308, accuracy = 0.875
# iteration (5150): loss = 0.416, accuracy = 0.859
# iteration (5200): loss = 0.220, accuracy = 0.945
# iteration (5250): loss = 0.227, accuracy = 0.930
# iteration (5300): loss = 0.313, accuracy = 0.914
# validation for epoch 13
# - epoch 13: validation accuracy = 0.800
# train for epoch 14
# iteration (5350): loss = 0.308, accuracy = 0.883
# iteration (5400): loss = 0.186, accuracy = 0.922
# iteration (5450): loss = 0.273, accuracy = 0.922
# iteration (5500): loss = 0.458, accuracy = 0.867
# iteration (5550): loss = 0.314, accuracy = 0.867
# iteration (5600): loss = 0.301, accuracy = 0.898
# iteration (5650): loss = 0.283, accuracy = 0.898
# iteration (5700): loss = 0.373, accuracy = 0.891
# validation for epoch 14
# - epoch 14: validation accuracy = 0.808
# train for epoch 15
# iteration (5750): loss = 0.175, accuracy = 0.938
# iteration (5800): loss = 0.334, accuracy = 0.859
# iteration (5850): loss = 0.272, accuracy = 0.906
# iteration (5900): loss = 0.462, accuracy = 0.867
# iteration (5950): loss = 0.440, accuracy = 0.891
# iteration (6000): loss = 0.480, accuracy = 0.836
# iteration (6050): loss = 0.214, accuracy = 0.922
# iteration (6100): loss = 0.283, accuracy = 0.891
# validation for epoch 15
# - epoch 15: validation accuracy = 0.812
# train for epoch 16
# iteration (6150): loss = 0.252, accuracy = 0.922
# iteration (6200): loss = 0.215, accuracy = 0.930
# iteration (6250): loss = 0.371, accuracy = 0.891
# iteration (6300): loss = 0.293, accuracy = 0.891
# iteration (6350): loss = 0.235, accuracy = 0.922
# iteration (6400): loss = 0.257, accuracy = 0.906
# iteration (6450): loss = 0.277, accuracy = 0.906
# validation for epoch 16
# - epoch 16: validation accuracy = 0.829
# train for epoch 17
# iteration (6500): loss = 0.253, accuracy = 0.930
# iteration (6550): loss = 0.237, accuracy = 0.898
# iteration (6600): loss = 0.461, accuracy = 0.883
# iteration (6650): loss = 0.261, accuracy = 0.898
# iteration (6700): loss = 0.290, accuracy = 0.938
# iteration (6750): loss = 0.253, accuracy = 0.883
# iteration (6800): loss = 0.312, accuracy = 0.898
# iteration (6850): loss = 0.200, accuracy = 0.930
# validation for epoch 17
# - epoch 17: validation accuracy = 0.838
# train for epoch 18
# iteration (6900): loss = 0.176, accuracy = 0.938
# iteration (6950): loss = 0.142, accuracy = 0.953
# iteration (7000): loss = 0.232, accuracy = 0.914
# iteration (7050): loss = 0.265, accuracy = 0.898
# iteration (7100): loss = 0.291, accuracy = 0.891
# iteration (7150): loss = 0.264, accuracy = 0.883
# iteration (7200): loss = 0.322, accuracy = 0.898
# iteration (7250): loss = 0.275, accuracy = 0.906
# validation for epoch 18
# - epoch 18: validation accuracy = 0.836
# train for epoch 19
# iteration (7300): loss = 0.231, accuracy = 0.945
# iteration (7350): loss = 0.115, accuracy = 0.953
# iteration (7400): loss = 0.229, accuracy = 0.930
# iteration (7450): loss = 0.238, accuracy = 0.922
# iteration (7500): loss = 0.228, accuracy = 0.906
# iteration (7550): loss = 0.181, accuracy = 0.938
# iteration (7600): loss = 0.233, accuracy = 0.922
# validation for epoch 19
# - epoch 19: validation accuracy = 0.820
# ***** test accuracy: 0.808
# Model saved in lib/tf_models/problem2/csci-599_mine.ckpt

# %%
tf.reset_default_graph()

# Load your model
model = YourModel()
sess = tf.Session()
saver = tf.train.Saver()
saver.restore(sess, "lib/tf_models/problem2/csci-599_mine.ckpt")
